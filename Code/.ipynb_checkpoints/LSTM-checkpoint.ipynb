# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Load the dataset
dataset_path = r"C:\\Users\\POOJA\\Desktop\\Major Project\\Datasets\\LSTM_ET_PM_2.csv"
df = pd.read_csv(dataset_path)

# Drop rows with missing values
df.dropna(inplace=True)

# Define features and target
features = ['MaxTemp', 'MinTemp', 'Humidity', 'Radiation', 'WindSpeed', 'Rainfall', 'ET_PM']
target = 'Sugarcane_Growth'

# Convert target to binary labels (Yes: 1, No: 0)
df[target] = df[target].apply(lambda x: 1 if x == 'Yes' else 0)

# Split data into features and target variable
X = df[features]
y = df[target]

# Normalize the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Reshape data for LSTM input (samples, time steps, features)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build LSTM model
model = Sequential()
model.add(LSTM(units=50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))

# Evaluate model
_, accuracy = model.evaluate(X_test, y_test)
print("Accuracy: %.2f%%" % (accuracy * 100))


# Make predictions
y_pred_proba = model.predict(X_test)
y_pred = (y_pred_proba > 0.5).astype(int)

# Convert predictions to Yes or No
predictions = ['Yes' if pred == 1 else 'No' for pred in y_pred]

# Add predictions to the original DataFrame
df_test = pd.DataFrame(X_test.reshape(X_test.shape[0], X_test.shape[1]), columns=features)
df_test['Predicted_Sugarcane_Growth'] = predictions

# Save predicted dataset to an Excel file
output_path ="C:\\Users\\POOJA\\Desktop\\Major Project\\Datasets\\LSTM_Predictions_2.csv"
df_test.to_csv(output_path, index=False)
print("Predictions saved to", output_path)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 5s 239ms/step - loss: 0.6900 - accuracy: 0.5472 - val_loss: 0.6772 - val_accuracy: 0.7500
# Epoch 2/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.6691 - accuracy: 0.7484 - val_loss: 0.6562 - val_accuracy: 0.7500
# Epoch 3/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.6476 - accuracy: 0.7484 - val_loss: 0.6350 - val_accuracy: 0.7500
# Epoch 4/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6251 - accuracy: 0.7484 - val_loss: 0.6136 - val_accuracy: 0.7500
# Epoch 5/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.6055 - accuracy: 0.7484 - val_loss: 0.5928 - val_accuracy: 0.7500
# Epoch 6/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5851 - accuracy: 0.7484 - val_loss: 0.5782 - val_accuracy: 0.7500
# Epoch 7/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5729 - accuracy: 0.7484 - val_loss: 0.5763 - val_accuracy: 0.7500
# Epoch 8/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.5742 - accuracy: 0.7484 - val_loss: 0.5787 - val_accuracy: 0.7500
# Epoch 9/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.5734 - accuracy: 0.7484 - val_loss: 0.5742 - val_accuracy: 0.7500
# Epoch 10/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.5690 - accuracy: 0.7484 - val_loss: 0.5720 - val_accuracy: 0.7500
# Epoch 11/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.5676 - accuracy: 0.7484 - val_loss: 0.5710 - val_accuracy: 0.7500
# Epoch 12/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5671 - accuracy: 0.7484 - val_loss: 0.5702 - val_accuracy: 0.7500
# Epoch 13/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.5661 - accuracy: 0.7484 - val_loss: 0.5694 - val_accuracy: 0.7500
# Epoch 14/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.5652 - accuracy: 0.7484 - val_loss: 0.5686 - val_accuracy: 0.7500
# Epoch 15/50
# 5/5 [==============================] - 0s 39ms/step - loss: 0.5641 - accuracy: 0.7484 - val_loss: 0.5678 - val_accuracy: 0.7500
# Epoch 16/50
# 5/5 [==============================] - 0s 38ms/step - loss: 0.5635 - accuracy: 0.7484 - val_loss: 0.5673 - val_accuracy: 0.7500
# Epoch 17/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5621 - accuracy: 0.7484 - val_loss: 0.5662 - val_accuracy: 0.7500
# Epoch 18/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5608 - accuracy: 0.7484 - val_loss: 0.5648 - val_accuracy: 0.7500
# Epoch 19/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.5593 - accuracy: 0.7484 - val_loss: 0.5635 - val_accuracy: 0.7500
# Epoch 20/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.5591 - accuracy: 0.7484 - val_loss: 0.5622 - val_accuracy: 0.7500
# Epoch 21/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.5569 - accuracy: 0.7484 - val_loss: 0.5606 - val_accuracy: 0.7500
# Epoch 22/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.5549 - accuracy: 0.7484 - val_loss: 0.5590 - val_accuracy: 0.7500
# Epoch 23/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5517 - accuracy: 0.7484 - val_loss: 0.5563 - val_accuracy: 0.7500
# Epoch 24/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.5487 - accuracy: 0.7484 - val_loss: 0.5530 - val_accuracy: 0.7500
# Epoch 25/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.5443 - accuracy: 0.7484 - val_loss: 0.5486 - val_accuracy: 0.7500
# Epoch 26/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5395 - accuracy: 0.7484 - val_loss: 0.5434 - val_accuracy: 0.7500
# Epoch 27/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.5318 - accuracy: 0.7484 - val_loss: 0.5345 - val_accuracy: 0.7500
# Epoch 28/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.5191 - accuracy: 0.7484 - val_loss: 0.5235 - val_accuracy: 0.7500
# Epoch 29/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.5029 - accuracy: 0.7484 - val_loss: 0.5083 - val_accuracy: 0.7500
# Epoch 30/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.4807 - accuracy: 0.7453 - val_loss: 0.4895 - val_accuracy: 0.7500
# Epoch 31/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4544 - accuracy: 0.7484 - val_loss: 0.4684 - val_accuracy: 0.8000
# Epoch 32/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4267 - accuracy: 0.7767 - val_loss: 0.4511 - val_accuracy: 0.8125
# Epoch 33/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3984 - accuracy: 0.8082 - val_loss: 0.4386 - val_accuracy: 0.8000
# Epoch 34/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3719 - accuracy: 0.8239 - val_loss: 0.4285 - val_accuracy: 0.8000
# Epoch 35/50
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3745 - accuracy: 0.8333 - val_loss: 0.4702 - val_accuracy: 0.8125
# Epoch 36/50
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3681 - accuracy: 0.8208 - val_loss: 0.4191 - val_accuracy: 0.7875
# Epoch 37/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3356 - accuracy: 0.8396 - val_loss: 0.4424 - val_accuracy: 0.8125
# Epoch 38/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3374 - accuracy: 0.8365 - val_loss: 0.4030 - val_accuracy: 0.8125
# Epoch 39/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3421 - accuracy: 0.8396 - val_loss: 0.4087 - val_accuracy: 0.8125
# Epoch 40/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3291 - accuracy: 0.8333 - val_loss: 0.3902 - val_accuracy: 0.8500
# Epoch 41/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3235 - accuracy: 0.8428 - val_loss: 0.3884 - val_accuracy: 0.8250
# Epoch 42/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3225 - accuracy: 0.8491 - val_loss: 0.3891 - val_accuracy: 0.8500
# Epoch 43/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3272 - accuracy: 0.8333 - val_loss: 0.3861 - val_accuracy: 0.8375
# Epoch 44/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3240 - accuracy: 0.8459 - val_loss: 0.3835 - val_accuracy: 0.8250
# Epoch 45/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.3202 - accuracy: 0.8491 - val_loss: 0.4081 - val_accuracy: 0.8125
# Epoch 46/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3155 - accuracy: 0.8616 - val_loss: 0.3838 - val_accuracy: 0.8125
# Epoch 47/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3237 - accuracy: 0.8208 - val_loss: 0.3895 - val_accuracy: 0.8500
# Epoch 48/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3120 - accuracy: 0.8365 - val_loss: 0.3809 - val_accuracy: 0.8250
# Epoch 49/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3223 - accuracy: 0.8459 - val_loss: 0.3861 - val_accuracy: 0.8250
# Epoch 50/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3109 - accuracy: 0.8491 - val_loss: 0.3801 - val_accuracy: 0.8250
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3801 - accuracy: 0.8250
# Accuracy: 82.50%
# 3/3 [==============================] - 1s 8ms/step
# Predictions saved to C:\Users\POOJA\Desktop\Major Project\Datasets\LSTM_Predictions_2.csv
